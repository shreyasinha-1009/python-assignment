# %%
n = int(input("enter the vlue of 'n':"))
a=0
b=1
sum=0
count=1
print("fibonacci series:",end= " ")
while(count<=n):
    print(sum,end=" ")
    count+=1
    a=b
    b=sum
    sum=a+b
# Out:
# enter the vlue of 'n': 7
# fibonacci series: 0 1 1 2 3 5 8
